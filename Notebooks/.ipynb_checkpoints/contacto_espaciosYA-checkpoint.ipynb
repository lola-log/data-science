# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
df = pd.read_csv('../datasets/Contacto_espaciosya.csv')
df
# Out:
#               ID de Contacto Propietario de Contacto  \
# 0   zcrm_4294866000000244364           Ariadna Souza
# 1   zcrm_4294866000000244567           Ariadna Souza
# 2   zcrm_4294866000000271010           Mabel Ciancio
# 3   zcrm_4294866000000271034           Mabel Ciancio
# 4   zcrm_4294866000000271214           Ariadna Souza
# 5   zcrm_4294866000000271408           Mabel Ciancio
# 6   zcrm_4294866000000271558           Ariadna Souza
# 7   zcrm_4294866000000271688           Mabel Ciancio
# 8   zcrm_4294866000000271736           Mabel Ciancio
# 9   zcrm_4294866000000279031           Ariadna Souza
# 10  zcrm_4294866000000279046           Ariadna Souza
# 11  zcrm_4294866000000279061           Ariadna Souza
# 12  zcrm_4294866000000279076           Ariadna Souza
# 13  zcrm_4294866000000368008           Ariadna Souza
# 14  zcrm_4294866000000368134           Mabel Ciancio
#
#    ID de propietario de Contacto Fuente de Posible cliente  \
# ...
